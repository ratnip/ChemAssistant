# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 64.4 MB/s eta 0:00:00

# %%
import streamlit as st

print(st.__version__)
# Out:
# 1.64.0

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/ChemASSistant"
# Out:
# /content/drive/MyDrive/Colab Notebooks/ChemASSistant

# %%
# !streamlit run streamlit_app.py --server.headless true > /tmp/streamlit.log 2>&1 &

# %%
# !curl -s http://localhost:8501/_stcore/health
# Out:
# ok
